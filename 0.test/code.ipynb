# %%
'Welcome to nares it'
# Out:
# 'Welcome to nares it'

# %%
3+3
# Out:
# 6

# %%
3*3
# Out:
# 9

# %%
2**3
# Out:
# 8

# %%
2-8+3
# Out:
# -3

# %%
2-8*3
# Out:
# -22

# %%
(2-8)*3
# Out:
# -18

# %%
'Welcome to nares it'
